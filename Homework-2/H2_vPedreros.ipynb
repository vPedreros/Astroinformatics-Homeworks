# %% [markdown]
# # **HOMEWORK 2**
#
# ## Vicente Pedreros Aballay 20.442.866-2

# %%
# Adjust width of notebook
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

# Basic libraries are imported
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Out:
# <style>.container { width:80% !important; }</style>

# %%
# Style for plotting
from astropy.visualization import astropy_mpl_style
plt.style.use(astropy_mpl_style)

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Vicente-Pedreros-Aballay-20.442.866-2" data-toc-modified-id="Vicente-Pedreros-Aballay-20.442.866-2-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Vicente Pedreros Aballay 20.442.866-2</a></span></li><li><span><a href="#Problem-1" data-toc-modified-id="Problem-1-2"><span class="toc-item-num">2&nbsp;&nbsp;</span><strong>Problem 1</strong></a></span><ul class="toc-item"><li><span><a href="#Part-a" data-toc-modified-id="Part-a-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Part a</a></span></li><li><span><a href="#Part-b" data-toc-modified-id="Part-b-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Part b</a></span></li><li><span><a href="#Part-c" data-toc-modified-id="Part-c-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Part c</a></span></li><li><span><a href="#Part-d" data-toc-modified-id="Part-d-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Part d</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## **Problem 1**

# %% [markdown]
# ### Part a

# %% [markdown]
# First, the data is imported and displayed.

# %%
df_labels = pd.read_pickle('dfcrossmatches_small.pickle')
display(df_labels)
# Out:
#              classALeRCE          ra        dec       period     source  \
# oid
# ZTF18aaveffj         LPV  291.520423  21.930962          NaN  GAIADR2VS
# ZTF19aauyvnv         LPV  270.298238 -17.722810          NaN  GAIADR2VS
# ZTF18ablqvvc         RRL  271.180157  -6.556286          NaN  GAIADR2VS
# ZTF19abiblfd         RRL  268.188213 -17.161156          NaN  GAIADR2VS
# ZTF18acbvvku         AGN   48.110790  39.274936          NaN  MILLIQUAS
# ...                  ...         ...        ...          ...        ...
# ZTF18aawgtde         QSO  235.612689  29.700747          NaN  MILLIQUAS
# ZTF18ablqnie         LPV  260.850159 -23.237702          NaN  GAIADR2VS
# ZTF19adcftsl         QSO  210.322714  22.715302          NaN  MILLIQUAS
# ZTF17aaaeblo         LPV   56.263632  56.318683  445.0268424  GAIADR2VS
# ZTF17aaawcpz       EB/EW    8.503472  38.867726    1.1774813     ASASSN
#
#                                  id_source class_source  separation_arcsec
# oid
# ZTF18aaveffj         2018953972876187648.0      MIRA_SR           0.067312
# ZTF19aauyvnv         4143774487177066496.0      MIRA_SR           0.062104
# ZTF18ablqvvc         4171403011041441792.0         RRAB           0.095138
# ZTF19abiblfd         4144758786310249984.0         RRAB           0.043913
# ZTF18acbvvku                      4C 39.11            A           0.055433
# ...                                    ...          ...                ...
# ZTF18aawgtde               FBQS J1542+2942            Q           0.384536
# ZTF18ablqnie         4111611813625888768.0      MIRA_SR           0.228594
# ZTF19adcftsl     LAMOSTJ140117.45+224255.2            Q           0.067727
# ZTF17aaaeblo          445693502249299968.0      MIRA_SR           0.133420
# ZTF17aaawcpz  ASASSN-V J003400.84+385203.9           EB           0.160370
#
# [50000 rows x 8 columns]

# %% [markdown]
# Next, a slice of the dataframe is done. In particular, the column "classALeRCE" is obtained.

# %%
classALeRCE = df_labels['classALeRCE']

# %% [markdown]
# To obtain the count of each class, value_counts is used. Then, the bar plot is done.

# %%
ax = classALeRCE.value_counts().plot.bar()
ax.set_title('Number of classes');

# %% [markdown]
# ### Part b

# %% [markdown]
# Data imported and displayed.
#
# The reason behind why the pickle filed is not in the same folder as this notebook, is because I'm using github and can't upload the file (exceeds the 100MB limit). This was the easiest solution for me. Sorry for that :c

# %%
df_features = pd.read_pickle('/home/vpedreros/Astroinformatics/features_small.pickle')
display(df_features)
# Out:
#                          name     value  fid        version
# oid
# ZTF17aaaabrg        Amplitude  0.242504    1  feature_0.0.1
# ZTF17aaaabrg        Amplitude  0.232499    2  feature_0.0.1
# ZTF17aaaabrg  AndersonDarling  1.000000    1  feature_0.0.1
# ZTF17aaaabrg  AndersonDarling  1.000000    2  feature_0.0.1
# ZTF17aaaabrg   Autocor_length  1.000000    1  feature_0.0.1
# ...                       ...       ...  ...            ...
# ZTF21abkylyc              Std  0.239856    2  feature_0.0.1
# ZTF21abkylyc         StetsonK       NaN    1  feature_0.0.1
# ZTF21abkylyc         StetsonK  0.886870    2  feature_0.0.1
# ZTF21abkylyc            W1-W2       NaN    0  feature_0.0.1
# ZTF21abkylyc            W2-W3       NaN    0  feature_0.0.1
#
# [6739900 rows x 4 columns]

# %% [markdown]
# Using pivot, a dataframe with multiindex columns is created, then displayed.

# %%
df_features_pv = df_features.pivot(columns=['name','fid'],values=['value'])
display(df_features_pv)
# Out:
#                  value                                                     \
# name         Amplitude           AndersonDarling           Autocor_length
# fid                 1         2               1         2              1
# oid
# ZTF17aaaabrg  0.242504  0.232499        1.000000  1.000000            1.0
# ZTF17aaaabtj  0.294114  0.216206        1.000000  1.000000            1.0
# ZTF17aaaacml  0.179008  0.162632        1.000000  1.000000            1.0
# ZTF17aaaacnc  0.199403  0.215955        1.000000  0.999978            1.0
# ZTF17aaaacnt  0.671062  0.498549        1.000000  0.775576            1.0
# ...                ...       ...             ...       ...            ...
# ZTF21abkjyui  0.683250       NaN        0.677959       NaN            1.0
# ZTF21abkndcw  0.617332       NaN        0.989514       NaN            1.0
# ZTF21abknlix  0.077879  0.075038        0.520365  0.386736            3.0
# ZTF21abkrimu       NaN  0.402185             NaN  1.000000            NaN
# ZTF21abkylyc       NaN  0.369650             NaN  0.576287            NaN
#
#                                                        ...            \
# name              Beyond1Std            Con            ...       Std
# fid            2          1         2    1         2   ...        2
# oid                                                    ...
# ZTF17aaaabrg  1.0   0.426471  0.361446  0.0  0.000000  ...  0.164944
# ZTF17aaaabtj  1.0   0.489510  0.390909  0.0  0.009259  ...  0.119271
# ZTF17aaaacml  1.0   0.403846  0.229508  0.0  0.000000  ...  0.115176
# ZTF17aaaacnc  1.0   0.062500  0.350000  0.0  0.000000  ...  0.102518
# ZTF17aaaacnt  1.0   0.242105  0.298246  0.0  0.000000  ...  0.271919
# ...           ...        ...       ...  ...       ...  ...       ...
# ZTF21abkjyui  NaN   0.333333       NaN  0.0       NaN  ...       NaN
# ZTF21abkndcw  NaN   0.166667       NaN  0.0       NaN  ...       NaN
# ZTF21abknlix  1.0   0.416667  0.285714  0.0  0.000000  ...  0.048887
# ZTF21abkrimu  1.0        NaN  0.322581  NaN  0.000000  ...  0.268336
# ZTF21abkylyc  1.0        NaN  0.250000  NaN  0.000000  ...  0.239856
#
#                                                                            \
# name          StetsonK                g-W2      g-W3 Power_rate      r-W2
# fid                 1         2         0         0          12        0
# oid
# ZTF17aaaabrg  0.912734  0.958511       NaN       NaN        NaN       NaN
# ZTF17aaaabtj  0.967987  0.758365       NaN       NaN        NaN       NaN
# ZTF17aaaacml  0.946447  0.786144       NaN       NaN        NaN       NaN
# ZTF17aaaacnc  0.525565  0.786877       NaN       NaN        NaN       NaN
# ZTF17aaaacnt  0.820105  0.772239       NaN       NaN        NaN       NaN
# ...                ...       ...       ...       ...        ...       ...
# ZTF21abkjyui  0.808906       NaN       NaN       NaN   0.000866       NaN
# ZTF21abkndcw  0.777093       NaN  2.248809  4.216808   0.000090  1.479431
# ZTF21abknlix  0.839430  0.776154  8.182998  8.388997   0.053091  5.690223
# ZTF21abkrimu       NaN  0.850610       NaN       NaN   0.002877       NaN
# ZTF21abkylyc       NaN  0.886870       NaN       NaN   0.184779       NaN
#
#
# name              r-W3     W1-W2     W2-W3
# fid                 0         0         0
# oid
# ZTF17aaaabrg       NaN       NaN       NaN
# ZTF17aaaabtj       NaN       NaN       NaN
# ZTF17aaaacml       NaN       NaN       NaN
# ZTF17aaaacnc       NaN       NaN       NaN
# ZTF17aaaacnt       NaN       NaN       NaN
# ...                ...       ...       ...
# ZTF21abkjyui       NaN       NaN       NaN
# ZTF21abkndcw  3.447430 -0.316000  1.967999
# ZTF21abknlix  5.896222  0.051001  0.205999
# ZTF21abkrimu       NaN       NaN       NaN
# ZTF21abkylyc       NaN       NaN       NaN
#
# [39024 rows x 179 columns]

# %% [markdown]
# A first attempt to obtain a single element, was made by just typing "pivot_df['Amplitude']", but that gave an error since I didn't noticed there was a "value" column in the dataframe. Then, I proceeded as usual.

# %%
df_features_pv['value']['Amplitude'][1][0]
# Out:
# 0.24250411987304688

# %% [markdown]
# ### Part c

# %% [markdown]
# The medians of each coumn is obtained.

# %%
medians = df_features_pv.median()
medians
# Out:
#        name             fid
# value  Amplitude        1      0.402083
#                         2      0.341036
#        AndersonDarling  1      0.999934
#                         2      0.999747
#        Autocor_length   1      1.000000
#                                  ...
#        Power_rate       12     0.029785
#        r-W2             0      4.645677
#        r-W3             0      7.501856
#        W1-W2            0      0.559000
#        W2-W3            0      2.527000
# Length: 179, dtype: float64

# %% [markdown]
# The NaN values are replaced by the corresponding median.

# %%
df_features_pv_nnan = df_features_pv.fillna(medians)
display(df_features_pv_nnan)
# Out:
#                  value                                                     \
# name         Amplitude           AndersonDarling           Autocor_length
# fid                 1         2               1         2              1
# oid
# ZTF17aaaabrg  0.242504  0.232499        1.000000  1.000000            1.0
# ZTF17aaaabtj  0.294114  0.216206        1.000000  1.000000            1.0
# ZTF17aaaacml  0.179008  0.162632        1.000000  1.000000            1.0
# ZTF17aaaacnc  0.199403  0.215955        1.000000  0.999978            1.0
# ZTF17aaaacnt  0.671062  0.498549        1.000000  0.775576            1.0
# ...                ...       ...             ...       ...            ...
# ZTF21abkjyui  0.683250  0.341036        0.677959  0.999747            1.0
# ZTF21abkndcw  0.617332  0.341036        0.989514  0.999747            1.0
# ZTF21abknlix  0.077879  0.075038        0.520365  0.386736            3.0
# ZTF21abkrimu  0.402083  0.402185        0.999934  1.000000            1.0
# ZTF21abkylyc  0.402083  0.369650        0.999934  0.576287            1.0
#
#                                                        ...            \
# name              Beyond1Std            Con            ...       Std
# fid            2          1         2    1         2   ...        2
# oid                                                    ...
# ZTF17aaaabrg  1.0   0.426471  0.361446  0.0  0.000000  ...  0.164944
# ZTF17aaaabtj  1.0   0.489510  0.390909  0.0  0.009259  ...  0.119271
# ZTF17aaaacml  1.0   0.403846  0.229508  0.0  0.000000  ...  0.115176
# ZTF17aaaacnc  1.0   0.062500  0.350000  0.0  0.000000  ...  0.102518
# ZTF17aaaacnt  1.0   0.242105  0.298246  0.0  0.000000  ...  0.271919
# ...           ...        ...       ...  ...       ...  ...       ...
# ZTF21abkjyui  1.0   0.333333  0.325000  0.0  0.000000  ...  0.212839
# ZTF21abkndcw  1.0   0.166667  0.325000  0.0  0.000000  ...  0.212839
# ZTF21abknlix  1.0   0.416667  0.285714  0.0  0.000000  ...  0.048887
# ZTF21abkrimu  1.0   0.329268  0.322581  0.0  0.000000  ...  0.268336
# ZTF21abkylyc  1.0   0.329268  0.250000  0.0  0.000000  ...  0.239856
#
#                                                                            \
# name          StetsonK                g-W2      g-W3 Power_rate      r-W2
# fid                 1         2         0         0          12        0
# oid
# ZTF17aaaabrg  0.912734  0.958511  4.943869  7.820271   0.029785  4.645677
# ZTF17aaaabtj  0.967987  0.758365  4.943869  7.820271   0.029785  4.645677
# ZTF17aaaacml  0.946447  0.786144  4.943869  7.820271   0.029785  4.645677
# ZTF17aaaacnc  0.525565  0.786877  4.943869  7.820271   0.029785  4.645677
# ZTF17aaaacnt  0.820105  0.772239  4.943869  7.820271   0.029785  4.645677
# ...                ...       ...       ...       ...        ...       ...
# ZTF21abkjyui  0.808906  0.825233  4.943869  7.820271   0.000866  4.645677
# ZTF21abkndcw  0.777093  0.825233  2.248809  4.216808   0.000090  1.479431
# ZTF21abknlix  0.839430  0.776154  8.182998  8.388997   0.053091  5.690223
# ZTF21abkrimu  0.834742  0.850610  4.943869  7.820271   0.002877  4.645677
# ZTF21abkylyc  0.834742  0.886870  4.943869  7.820271   0.184779  4.645677
#
#
# name              r-W3     W1-W2     W2-W3
# fid                 0         0         0
# oid
# ZTF17aaaabrg  7.501856  0.559000  2.527000
# ZTF17aaaabtj  7.501856  0.559000  2.527000
# ZTF17aaaacml  7.501856  0.559000  2.527000
# ZTF17aaaacnc  7.501856  0.559000  2.527000
# ZTF17aaaacnt  7.501856  0.559000  2.527000
# ...                ...       ...       ...
# ZTF21abkjyui  7.501856  0.559000  2.527000
# ZTF21abkndcw  3.447430 -0.316000  1.967999
# ZTF21abknlix  5.896222  0.051001  0.205999
# ZTF21abkrimu  7.501856  0.559000  2.527000
# ZTF21abkylyc  7.501856  0.559000  2.527000
#
# [39024 rows x 179 columns]

# %% [markdown]
# ### Part d

# %% [markdown]
# The dataframes containing labels and features are concatenated. This is done by adding the columns containing fatures to the first dataframe (labels).

# %%
new_df = pd.concat([df_labels, df_features_pv_nnan], axis=1)
display(new_df)
# Out:
#              classALeRCE          ra        dec       period     source  \
# oid
# ZTF18aaveffj         LPV  291.520423  21.930962          NaN  GAIADR2VS
# ZTF19aauyvnv         LPV  270.298238 -17.722810          NaN  GAIADR2VS
# ZTF18ablqvvc         RRL  271.180157  -6.556286          NaN  GAIADR2VS
# ZTF19abiblfd         RRL  268.188213 -17.161156          NaN  GAIADR2VS
# ZTF18acbvvku         AGN   48.110790  39.274936          NaN  MILLIQUAS
# ...                  ...         ...        ...          ...        ...
# ZTF18aawgtde         QSO  235.612689  29.700747          NaN  MILLIQUAS
# ZTF18ablqnie         LPV  260.850159 -23.237702          NaN  GAIADR2VS
# ZTF19adcftsl         QSO  210.322714  22.715302          NaN  MILLIQUAS
# ZTF17aaaeblo         LPV   56.263632  56.318683  445.0268424  GAIADR2VS
# ZTF17aaawcpz       EB/EW    8.503472  38.867726    1.1774813     ASASSN
#
#                                  id_source class_source  separation_arcsec  \
# oid
# ZTF18aaveffj         2018953972876187648.0      MIRA_SR           0.067312
# ZTF19aauyvnv         4143774487177066496.0      MIRA_SR           0.062104
# ZTF18ablqvvc         4171403011041441792.0         RRAB           0.095138
# ZTF19abiblfd         4144758786310249984.0         RRAB           0.043913
# ZTF18acbvvku                      4C 39.11            A           0.055433
# ...                                    ...          ...                ...
# ZTF18aawgtde               FBQS J1542+2942            Q           0.384536
# ZTF18ablqnie         4111611813625888768.0      MIRA_SR           0.228594
# ZTF19adcftsl     LAMOSTJ140117.45+224255.2            Q           0.067727
# ZTF17aaaeblo          445693502249299968.0      MIRA_SR           0.133420
# ZTF17aaawcpz  ASASSN-V J003400.84+385203.9           EB           0.160370
#
#               (value, Amplitude, 1)  (value, Amplitude, 2)  ...  \
# oid                                                         ...
# ZTF18aaveffj               0.264278               0.363577  ...
# ZTF19aauyvnv               0.402083               0.341036  ...
# ZTF18ablqvvc               0.402083               0.100148  ...
# ZTF19abiblfd                    NaN                    NaN  ...
# ZTF18acbvvku               0.849506               0.653158  ...
# ...                             ...                    ...  ...
# ZTF18aawgtde               0.072512               0.064309  ...
# ZTF18ablqnie                    NaN                    NaN  ...
# ZTF19adcftsl               0.183510               0.341036  ...
# ZTF17aaaeblo               2.309970               1.347452  ...
# ZTF17aaawcpz               0.621127               0.479609  ...
#
#               (value, Std, 2)  (value, StetsonK, 1)  (value, StetsonK, 2)  \
# oid
# ZTF18aaveffj         0.195895              0.808636              0.822968
# ZTF19aauyvnv         0.212839              0.834742              0.825233
# ZTF18ablqvvc         0.053437              0.834742              0.821775
# ZTF19abiblfd              NaN                   NaN                   NaN
# ZTF18acbvvku         0.405141              0.909260              0.886437
# ...                       ...                   ...                   ...
# ZTF18aawgtde         0.035427              0.819063              0.758283
# ZTF18ablqnie              NaN                   NaN                   NaN
# ZTF19adcftsl         0.212839              0.861115              0.825233
# ZTF17aaaeblo         0.745226              0.872072              0.904087
# ZTF17aaawcpz         0.224842              0.735645              0.822329
#
#               (value, g-W2, 0)  (value, g-W3, 0)  (value, Power_rate, 12)  \
# oid
# ZTF18aaveffj          4.943869          7.820271                 0.029785
# ZTF19aauyvnv          4.943869          7.820271                 0.029785
# ZTF18ablqvvc          4.943869          7.820271                 0.029785
# ZTF19abiblfd               NaN               NaN                      NaN
# ZTF18acbvvku          4.943869          7.820271                 0.029785
# ...                        ...               ...                      ...
# ZTF18aawgtde          4.943869          7.820271                 0.029785
# ZTF18ablqnie               NaN               NaN                      NaN
# ZTF19adcftsl          5.867576          9.412576                 0.004110
# ZTF17aaaeblo          4.943869          7.820271                 0.029785
# ZTF17aaawcpz          4.943869          7.820271                 0.029785
#
#               (value, r-W2, 0)  (value, r-W3, 0)  (value, W1-W2, 0)  \
# oid
# ZTF18aaveffj          4.645677          7.501856              0.559
# ZTF19aauyvnv          4.645677          7.501856              0.559
# ZTF18ablqvvc          4.645677          7.501856              0.559
# ZTF19abiblfd               NaN               NaN                NaN
# ZTF18acbvvku          4.645677          7.501856              0.559
# ...                        ...               ...                ...
# ZTF18aawgtde          4.645677          7.501856              0.559
# ZTF18ablqnie               NaN               NaN                NaN
# ZTF19adcftsl          5.385038          8.930038              1.265
# ZTF17aaaeblo          4.645677          7.501856              0.559
# ZTF17aaawcpz          4.645677          7.501856              0.559
#
#               (value, W2-W3, 0)
# oid
# ZTF18aaveffj              2.527
# ZTF19aauyvnv              2.527
# ZTF18ablqvvc              2.527
# ZTF19abiblfd                NaN
# ZTF18acbvvku              2.527
# ...                         ...
# ZTF18aawgtde              2.527
# ZTF18ablqnie                NaN
# ZTF19adcftsl              3.545
# ZTF17aaaeblo              2.527
# ZTF17aaawcpz              2.527
#
# [50000 rows x 187 columns]

# %%
new_df.dropna(inplace=True)
display(new_df)
# Out:
#              classALeRCE          ra        dec       period     source  \
# oid
# ZTF18acusmwa         RRL  161.238890   2.381415    0.3233030  CRTSnorth
# ZTF19acmgntk       EB/EW   26.987620  36.923154     0.301382  CRTSnorth
# ZTF18abmvguy         RRL  298.812374 -24.065799    0.5768394  GAIADR2VS
# ZTF18aabfvqe       EB/EW   79.054117   8.294285       0.3771  CRTSnorth
# ZTF18accaufk         RRL  286.328593  51.268229       0.3562     ASASSN
# ...                  ...         ...        ...          ...        ...
# ZTF19aaxkguq         RRL  239.787100 -24.623929     0.634849  GAIADR2VS
# ZTF20abfhbkh       EB/EW   34.752117  22.608598     0.294792  CRTSnorth
# ZTF19aarauin         RRL  171.825527 -23.179639      0.49407  CRTSsouth
# ZTF17aaaeblo         LPV   56.263632  56.318683  445.0268424  GAIADR2VS
# ZTF17aaawcpz       EB/EW    8.503472  38.867726    1.1774813     ASASSN
#
#                                  id_source class_source  separation_arcsec  \
# oid
# ZTF18acusmwa               1101058051006.0          RRc           0.633244
# ZTF19acmgntk               1138008006929.0           EW           1.146676
# ZTF18abmvguy         6851521431915793408.0         RRAB           0.052415
# ZTF18aabfvqe               1107028096412.0           EW           0.948262
# ZTF18accaufk  ASASSN-V J190518.88+511605.6          RRC           0.351361
# ...                                    ...          ...                ...
# ZTF19aaxkguq         6236136731041603584.0         RRAB           0.033218
# ZTF20abfhbkh               1123012001028.0           EW           0.365677
# ZTF19aarauin               3023080017887.0      Blazkho           0.329691
# ZTF17aaaeblo          445693502249299968.0      MIRA_SR           0.133420
# ZTF17aaawcpz  ASASSN-V J003400.84+385203.9           EB           0.160370
#
#               (value, Amplitude, 1)  (value, Amplitude, 2)  ...  \
# oid                                                         ...
# ZTF18acusmwa               0.299761               0.214768  ...
# ZTF19acmgntk               0.502189               0.446250  ...
# ZTF18abmvguy               0.569722               0.393913  ...
# ZTF18aabfvqe               0.248260               0.239684  ...
# ZTF18accaufk               0.852673               0.677350  ...
# ...                             ...                    ...  ...
# ZTF19aaxkguq               0.673977               0.420939  ...
# ZTF20abfhbkh               0.402083               0.395807  ...
# ZTF19aarauin               0.587070               0.565650  ...
# ZTF17aaaeblo               2.309970               1.347452  ...
# ZTF17aaawcpz               0.621127               0.479609  ...
#
#               (value, Std, 2)  (value, StetsonK, 1)  (value, StetsonK, 2)  \
# oid
# ZTF18acusmwa         0.165384              0.908949              0.935476
# ZTF19acmgntk         0.255419              0.799603              0.758067
# ZTF18abmvguy         0.271526              0.921541              0.885807
# ZTF18aabfvqe         0.180796              0.841988              0.879630
# ZTF18accaufk         0.380020              0.779443              0.808921
# ...                       ...                   ...                   ...
# ZTF19aaxkguq         0.255423              0.859329              0.919019
# ZTF20abfhbkh         0.186415              0.834742              0.817582
# ZTF19aarauin         0.319543              0.888937              0.912618
# ZTF17aaaeblo         0.745226              0.872072              0.904087
# ZTF17aaawcpz         0.224842              0.735645              0.822329
#
#               (value, g-W2, 0)  (value, g-W3, 0)  (value, Power_rate, 12)  \
# oid
# ZTF18acusmwa          4.943869          7.820271                 0.029785
# ZTF19acmgntk          4.943869          7.820271                 0.029785
# ZTF18abmvguy          4.943869          7.820271                 0.029785
# ZTF18aabfvqe          4.943869          7.820271                 0.029785
# ZTF18accaufk          4.943869          7.820271                 0.029785
# ...                        ...               ...                      ...
# ZTF19aaxkguq          4.943869          7.820271                 0.029785
# ZTF20abfhbkh          4.943869          7.820271                 0.006002
# ZTF19aarauin          4.943869          7.820271                 0.029785
# ZTF17aaaeblo          4.943869          7.820271                 0.029785
# ZTF17aaawcpz          4.943869          7.820271                 0.029785
#
#               (value, r-W2, 0)  (value, r-W3, 0)  (value, W1-W2, 0)  \
# oid
# ZTF18acusmwa          4.645677          7.501856              0.559
# ZTF19acmgntk          4.645677          7.501856              0.559
# ZTF18abmvguy          4.645677          7.501856              0.559
# ZTF18aabfvqe          4.645677          7.501856              0.559
# ZTF18accaufk          4.645677          7.501856              0.559
# ...                        ...               ...                ...
# ZTF19aaxkguq          4.645677          7.501856              0.559
# ZTF20abfhbkh          4.645677          7.501856              0.559
# ZTF19aarauin          4.645677          7.501856              0.559
# ZTF17aaaeblo          4.645677          7.501856              0.559
# ZTF17aaawcpz          4.645677          7.501856              0.559
#
#               (value, W2-W3, 0)
# oid
# ZTF18acusmwa              2.527
# ZTF19acmgntk              2.527
# ZTF18abmvguy              2.527
# ZTF18aabfvqe              2.527
# ZTF18accaufk              2.527
# ...                         ...
# ZTF19aaxkguq              2.527
# ZTF20abfhbkh              2.527
# ZTF19aarauin              2.527
# ZTF17aaaeblo              2.527
# ZTF17aaawcpz              2.527
#
# [18338 rows x 187 columns]
